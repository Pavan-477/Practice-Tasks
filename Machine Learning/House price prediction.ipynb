# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('House price train.csv')
dft=pd.read_csv('House price test.csv')

# %%
print(df.isna().sum())
print('-'*30)
print(dft.isna().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64
# ------------------------------
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
df.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
dft.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage       LotArea Street  \
# count   1459.000000  1459.000000     1455  1232.000000   1459.000000   1459
# unique          NaN          NaN        5          NaN           NaN      2
# top             NaN          NaN       RL          NaN           NaN   Pave
# freq            NaN          NaN     1114          NaN           NaN   1453
# mean    2190.000000    57.378341      NaN    68.580357   9819.161069    NaN
# std      421.321334    42.746880      NaN    22.376841   4955.517327    NaN
# min     1461.000000    20.000000      NaN    21.000000   1470.000000    NaN
# 25%     1825.500000    20.000000      NaN    58.000000   7391.000000    NaN
# 50%     2190.000000    50.000000      NaN    67.000000   9399.000000    NaN
# 75%     2554.500000    70.000000      NaN    80.000000  11517.500000    NaN
# max     2919.000000   190.000000      NaN   200.000000  56600.000000    NaN
#
# ...

# %%
df=df.drop_duplicates()
dft=dft.drop_duplicates()

# %%
df.info()
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
dft.isna().sum().sort_values(ascending=False).head(35)
# Out:
# PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# FireplaceQu      730
# LotFrontage      227
# GarageYrBlt       78
# GarageQual        78
# GarageFinish      78
# GarageCond        78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrType        16
# MasVnrArea        15
# MSZoning           4
# BsmtHalfBath       2
# Utilities          2
# Functional         2
# BsmtFullBath       2
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# KitchenQual        1
# TotalBsmtSF        1
# Exterior2nd        1
# GarageCars         1
# Exterior1st        1
# GarageArea         1
# SaleType           1
# MiscVal            0
# BedroomAbvGr       0
# dtype: int64

# %%
df['LotArea'].corr(df['LotFrontage'])
# Out:
# 0.42609501877180816

# %%
df['MasVnrArea']=df['MasVnrArea'].fillna(df['MasVnrArea'].median())

df['MasVnrType']=df['MasVnrType'].fillna(df['MasVnrType'].mode()[0])

df['LotFrontage']=df['LotFrontage'].fillna(df['LotFrontage'].median())

df['BsmtQual']=df['BsmtQual'].fillna(df['BsmtQual'].mode()[0])

# %%
#SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
#LotFrontage: Linear feet of street connected to property
#Street: Type of road access
#LotShape: General shape of property
#LandContour: Flatness of the property
#Utilities: Type of utilities available
#LotConfig: Lot configuration
#Condition1: Proximity to main road or railroad
#Condition2: Proximity to main road or railroad (if a second is present)
#BldgType: Type of dwelling
#OverallQual: Overall material and finish quality
#YearRemodAdd: Remodel date
#Exterior2nd: Exterior covering on house (if more than one material)
#MasVnrType: Masonry veneer type
#MasVnrArea: Masonry veneer area in square feet
#ExterQual: Exterior material quality
#ExterCond: Present condition of the material on the exterior
#Foundation: Type of foundation
#BsmtQual: Height of the basement

# %%
dft_new=dft[[ 'LotFrontage', 'Street', 'LotShape', 'LandContour',
       'Utilities', 'LotConfig', 'Condition1',  'BldgType',
       'OverallQual', 'YearRemodAdd', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual']]

ndf=df[[ 'SalePrice','LotFrontage', 'Street', 'LotShape', 'LandContour',
       'Utilities', 'LotConfig', 'Condition1',  'BldgType',
       'OverallQual', 'YearRemodAdd', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual']]

# %%
print(dft_new.shape)
print(ndf.shape)
# Out:
# (1459, 17)
# (1460, 18)

# %%
dft_new.isna().sum()
# Out:
# LotFrontage     227
# Street            0
# LotShape          0
# LandContour       0
# Utilities         2
# LotConfig         0
# Condition1        0
# BldgType          0
# OverallQual       0
# YearRemodAdd      0
# Exterior2nd       1
# MasVnrType       16
# MasVnrArea       15
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         44
# dtype: int64

# %%
dft_new['MasVnrArea']=dft_new['MasVnrArea'].fillna(dft_new['MasVnrArea'].median())

dft_new['MasVnrType']=dft_new['MasVnrType'].fillna(dft_new['MasVnrType'].mode()[0])

dft_new['LotFrontage']=dft_new['LotFrontage'].fillna(dft_new['LotFrontage'].median())

dft_new['BsmtQual']=dft_new['BsmtQual'].fillna(dft_new['BsmtQual'].mode()[0])

dft_new['Exterior2nd']=dft_new['Exterior2nd'].fillna(dft_new['Exterior2nd'].mode()[0])
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_2156\2544399424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft_new['MasVnrArea']=dft_new['MasVnrArea'].fillna(dft_new['MasVnrArea'].median())
# C:\Users\pavan\AppData\Local\Temp\ipykernel_2156\2544399424.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft_new['MasVnrType']=dft_new['MasVnrType'].fillna(dft_new['MasVnrType'].mode()[0])
# C:\Users\pavan\AppData\Local\Temp\ipykernel_2156\2544399424.py:5: SettingWithCopyWarning:
# ...

# %%
dft_new.isna().sum()
# Out:
# LotFrontage     0
# Street          0
# LotShape        0
# LandContour     0
# Utilities       2
# LotConfig       0
# Condition1      0
# BldgType        0
# OverallQual     0
# YearRemodAdd    0
# Exterior2nd     0
# MasVnrType      0
# MasVnrArea      0
# ExterQual       0
# ExterCond       0
# Foundation      0
# BsmtQual        0
# dtype: int64

# %%
df['Utilities'].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
ndf['Utilities'].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
dft_new.drop('Utilities',axis=1,inplace=True)
ndf.drop('Utilities',axis=1,inplace=True)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_2156\3249095836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft_new.drop('Utilities',axis=1,inplace=True)
# C:\Users\pavan\AppData\Local\Temp\ipykernel_2156\3249095836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf.drop('Utilities',axis=1,inplace=True)

# %%
print(dft_new.shape)
print(ndf.shape)
# Out:
# (1459, 16)
# (1460, 17)

# %%
ndf.isna().sum()
# Out:
# SalePrice       0
# LotFrontage     0
# Street          0
# LotShape        0
# LandContour     0
# LotConfig       0
# Condition1      0
# BldgType        0
# OverallQual     0
# YearRemodAdd    0
# Exterior2nd     0
# MasVnrType      0
# MasVnrArea      0
# ExterQual       0
# ExterCond       0
# Foundation      0
# BsmtQual        0
# dtype: int64

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1459
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SalePrice     1460 non-null   int64
#  1   LotFrontage   1460 non-null   float64
#  2   Street        1460 non-null   object
#  3   LotShape      1460 non-null   object
#  4   LandContour   1460 non-null   object
#  5   LotConfig     1460 non-null   object
#  6   Condition1    1460 non-null   object
#  7   BldgType      1460 non-null   object
#  8   OverallQual   1460 non-null   int64
#  9   YearRemodAdd  1460 non-null   int64
#  10  Exterior2nd   1460 non-null   object
#  11  MasVnrType    1460 non-null   object
#  12  MasVnrArea    1460 non-null   float64
#  13  ExterQual     1460 non-null   object
#  14  ExterCond     1460 non-null   object
#  15  Foundation    1460 non-null   object
#  16  BsmtQual      1460 non-null   object
# dtypes: float64(2), int64(3), object(12)
# ...

# %%
ndf['BsmtQual'].describe()
# Out:
# count     1460
# unique       4
# top         TA
# freq       686
# Name: BsmtQual, dtype: object

# %%
ndf_c=set(ndf.columns)

disc={'Street', 'LotShape', 'LandContour','LotConfig', 'Condition1',  'BldgType',
        'Exterior2nd', 'MasVnrType','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual'}

num=ndf_c.difference(disc)

# %%
for i in disc:
    print(i)
    print('Train count:',ndf[i].nunique())
    print('Test count:',dft_new[i].nunique())
    print('-'*50)
# Out:
# LotShape
# Train count: 4
# Test count: 4
# --------------------------------------------------
# Street
# Train count: 2
# Test count: 2
# --------------------------------------------------
# ExterQual
# Train count: 4
# Test count: 4
# --------------------------------------------------
# Exterior2nd
# Train count: 16
# Test count: 15
# --------------------------------------------------
# Condition1
# Train count: 9
# Test count: 9
# --------------------------------------------------
# BldgType
# Train count: 5
# Test count: 5
# --------------------------------------------------
# MasVnrType
# Train count: 4
# Test count: 4
# --------------------------------------------------
# LandContour
# Train count: 4
# Test count: 4
# --------------------------------------------------
# Foundation
# Train count: 6
# Test count: 6
# --------------------------------------------------
# ExterCond
# Train count: 5
# Test count: 5
# --------------------------------------------------
# BsmtQual
# ...

# %%
print('Test',dft_new['Exterior2nd'].unique())
print('Train',ndf['Exterior2nd'].unique())
# Out:
# Test ['VinylSd' 'Wd Sdng' 'HdBoard' 'Plywood' 'MetalSd' 'Brk Cmn' 'CmentBd'
#  'ImStucc' 'Wd Shng' 'AsbShng' 'Stucco' 'CBlock' 'BrkFace' 'AsphShn'
#  'Stone']
# Train ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']

# %%
for j in disc:
    for i in num:
        if i =='SalePrice':
            continue
        else:
            sns.scatterplot(y=ndf['SalePrice'],x=ndf[i],hue=df[j])
            plt.show()
    print('-'*60)
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
for i in num:
    sns.boxplot(ndf[i])
    plt.show()
# Out:
# C:\Users\pavan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pavan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pavan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
q1=ndf['LotFrontage'].quantile(0.25)
q3=ndf['LotFrontage'].quantile(0.75)
iqr= q3-q1
ll = q1-(1.5 *iqr)
ul = q3+(1.5*iqr)
ndf[(ndf['LotFrontage']<ll) & (ndf['LotFrontage']>ul) ]
# Out:
# Empty DataFrame
# Columns: [SalePrice, LotFrontage, Street, LotShape, LandContour, LotConfig, Condition1, BldgType, OverallQual, YearRemodAdd, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual]
# Index: []

# %%
m=ndf['LotFrontage'].mean()
sd=ndf['LotFrontage'].std()

ll = m-(3*sd)
ul = m+(3*sd)
ndf[(ndf['LotFrontage']<ll) & (ndf['LotFrontage']>ul) ]
# Out:
# Empty DataFrame
# Columns: [SalePrice, LotFrontage, Street, LotShape, LandContour, LotConfig, Condition1, BldgType, OverallQual, YearRemodAdd, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual]
# Index: []

# %%
X=ndf.drop('SalePrice',axis=1)
y=ndf['SalePrice']

# %%
X=pd.concat([X,dft_new],axis=0,keys=['Train','Test'])

X=pd.get_dummies(data=X,drop_first=True)

# %%
X.loc['Train']
# Out:
#       LotFrontage  OverallQual  YearRemodAdd  MasVnrArea  Street_Pave  \
# 0            65.0            7          2003       196.0            1
# 1            80.0            6          1976         0.0            1
# 2            68.0            7          2002       162.0            1
# 3            60.0            7          1970         0.0            1
# 4            84.0            8          2000       350.0            1
# ...           ...          ...           ...         ...          ...
# 1455         62.0            6          2000         0.0            1
# 1456         85.0            6          1988       119.0            1
# 1457         66.0            7          2006         0.0            1
# 1458         68.0            5          1996         0.0            1
# 1459         75.0            5          1965         0.0            1
#
#       LotShape_IR2  LotShape_IR3  LotShape_Reg  LandContour_HLS  \
# ...

# %%
x=X.loc['Train']
dft_new=X.loc['Test']

# %%
print(dft_new.shape)
print(x.shape)
# Out:
# (1459, 60)
# (1460, 60)

# %%
x.isna().sum().sort_values(ascending=False)
# Out:
# LotFrontage            0
# OverallQual            0
# Exterior2nd_HdBoard    0
# Exterior2nd_ImStucc    0
# Exterior2nd_MetalSd    0
# Exterior2nd_Other      0
# Exterior2nd_Plywood    0
# Exterior2nd_Stone      0
# Exterior2nd_Stucco     0
# Exterior2nd_VinylSd    0
# Exterior2nd_Wd Sdng    0
# Exterior2nd_Wd Shng    0
# MasVnrType_BrkFace     0
# MasVnrType_None        0
# MasVnrType_Stone       0
# ExterQual_Fa           0
# ExterQual_Gd           0
# ExterQual_TA           0
# ExterCond_Fa           0
# ExterCond_Gd           0
# ExterCond_Po           0
# ExterCond_TA           0
# Foundation_CBlock      0
# Foundation_PConc       0
# Foundation_Slab        0
# Foundation_Stone       0
# Foundation_Wood        0
# BsmtQual_Fa            0
# BsmtQual_Gd            0
# Exterior2nd_CmentBd    0
# Exterior2nd_CBlock     0
# Exterior2nd_BrkFace    0
# LotConfig_Inside       0
# YearRemodAdd           0
# MasVnrArea             0
# Street_Pave            0
# LotShape_IR2           0
# ...

# %%
x=x.fillna(0)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
sc=StandardScaler()
errors={}

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=42)

xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

model=LinearRegression()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['Linear Regression']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.7597356435258392
# Test acc 0.744384309218921
# --------------------------------------------------
# RMSE 38193.61016167612

# %%
from sklearn.linear_model import Lasso

model=Lasso()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['Lasso Regression']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.7597355372159237
# Test acc 0.7444221835115539
# --------------------------------------------------
# RMSE 38193.61861145012

# %%
from sklearn.linear_model import Ridge

model=Ridge()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['Ridge Regression']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.7597317438581566
# Test acc 0.7444513446622041
# --------------------------------------------------
# RMSE 38193.920115647365

# %%
from sklearn.linear_model import ElasticNet

model=ElasticNet()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['ElasticNet Regression']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.7030433555580937
# Test acc 0.6952298595371975
# --------------------------------------------------
# RMSE 42461.22905556152

# %%
from sklearn.svm import SVR

model=SVR()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['SVR']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc -0.0451215636577591
# Test acc -0.025397399039980062
# --------------------------------------------------
# RMSE 79658.00793768182

# %%
from sklearn.neighbors import KNeighborsRegressor

model=KNeighborsRegressor()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['KNeighbours Regression']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.7228588777941418
# Test acc 0.5971068185826554
# --------------------------------------------------
# RMSE 41020.08187360993

# %%
from sklearn.tree import DecisionTreeRegressor

model=DecisionTreeRegressor()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['Decision Tree Regressor']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.9995173050957196
# Test acc 0.6470343847768768
# --------------------------------------------------
# RMSE 1711.9157766022265

# %%
from sklearn.model_selection import KFold
fold=KFold(10)

# %%
from sklearn.linear_model import Ridge

model=Ridge()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)

from sklearn.model_selection import cross_val_score
res=cross_val_score(model,x,y,cv=10)
# Out:
# --------------------------------------------------
# Train acc 0.7597317438581566
# Test acc 0.7444513446622041
# --------------------------------------------------

# %%
from sklearn.ensemble import GradientBoostingRegressor

model=GradientBoostingRegressor()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['GradientBoosting Regressor']=np.sqrt(mean_squared_error(ytrain,train_pred))
# Out:
# --------------------------------------------------
# Train acc 0.8734623050318109
# Test acc 0.795028903121999
# --------------------------------------------------
# RMSE 27717.62385121399

# %%
from sklearn.ensemble import RandomForestRegressor

model=RandomForestRegressor()
model.fit(xtrain,ytrain)
train_pred=model.predict(xtrain)
test_pred=model.predict(xtest)
print('-'*50)
print('Train acc',r2_score(ytrain,train_pred))
print('Test acc',r2_score(ytest,test_pred))
print('-'*50)
print('RMSE',np.sqrt(mean_squared_error(ytrain,train_pred)))
errors['RandomForest Regressor']=np.sqrt(mean_squared_error(ytrain,train_pred))
from sklearn.model_selection import cross_val_score
res=cross_val_score(model,x,y,cv=10)
res.mean()
# Out:
# --------------------------------------------------
# Train acc 0.9589798852789254
# Test acc 0.7835695024175793
# --------------------------------------------------
# RMSE 15781.361658034484
# 0.7492983482884517

# %%
errors
# Out:
# {'Linear Regression': 38193.61016167612,
#  'Lasso Regression': 38193.61861145012,
#  'Ridge Regression': 38193.920115647365,
#  'ElasticNet Regression': 42461.22905556152,
#  'SVR': 79658.00793768182,
#  'KNeighbours Regression': 41020.08187360993,
#  'Decision Tree Regressor': 1711.9157766022265,
#  'GradientBoosting Regressor': 27717.62385121399,
#  'RandomForest Regressor': 15781.361658034484}

# %% [markdown]
# ### Decision Tree has the lowest RMSE , but its test accuracy is low and its accuracy on Testing.csv is even worse
# ### So going with the next best RandomForestRegressor

# %% [markdown]
# ###  Predicting for test.csv

# %%
xt=sc.fit_transform(dft_new)

submission_pred=model.predict(xt)

df_sub=pd.DataFrame(submission_pred,columns=['SalePrice'])

df_sub['Id']=[x for x in range(1461,1461+submission_pred.shape[0])]

df_sub=df_sub[['Id','SalePrice']]

df_sub.to_csv('RFRSubmission.csv',index=False)
